# %% [markdown]
# # Step 1: Install Dependencies

# %%
# Install dependencies
# !pip install torch torchaudio transformers phonemizer gradio librosa scipy pydub
# !apt-get install espeak-ng -y  # Required for phonemizer

# %% [markdown]
# # Step 2: Clone the F5-TTS Repository

# %%
# Clone the F5-TTS repository
# !git clone https://github.com/SWivid/F5-TTS.git
# %cd F5-TTS

# %% [markdown]
# # Step 3: Download Pretrained Models

# %%
# Download pretrained models (replace 'YOUR_MODEL_DOWNLOAD_LINK' with the actual link)
# !mkdir -p models
# !wget -O models/pretrained_model.pth "YOUR_MODEL_DOWNLOAD_LINK"

# %% [markdown]
# # Step 4: Run Inference

# %%
import torch
from infer import infer_tts  # Ensure this path is correct

# Generate speech from text
text_input = "नमस्ते! यह मेरा हिंदी टेक्स्ट टू स्पीच मॉडल है।"
output_audio = "output.wav"

# Assuming infer_tts function takes text and output file path as arguments
infer_tts(text_input, output_audio)

# %% [markdown]
# # Step 5: Play the Generated Audio

# %%
import librosa
import IPython.display as ipd

# Load and play the generated audio
audio_data, sample_rate = librosa.load(output_audio, sr=None)
ipd.Audio(audio_data, rate=sample_rate)

# %% [markdown]
# #
